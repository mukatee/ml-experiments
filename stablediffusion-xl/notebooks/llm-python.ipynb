# %%
from diffusers import StableDiffusionXLPipeline
import torch

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipe.to("cuda")

#prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
#image = pipe(prompt=prompt).images[0]
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# StableDiffusionXLPipeline {
#   "_class_name": "StableDiffusionXLPipeline",
#   "_diffusers_version": "0.19.3",
#   "_name_or_path": "stabilityai/stable-diffusion-xl-base-1.0",
#   "force_zeros_for_empty_prompt": true,
#   "scheduler": [
#     "diffusers",
#     "EulerDiscreteScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "text_encoder_2": [
#     "transformers",
#     "CLIPTextModelWithProjection"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "tokenizer_2": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
#image

# %%
prompt = "Large language model writes python code"
images = pipe(prompt=prompt).images
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#images[0]

# %%
from diffusers import StableDiffusionXLPipeline
import torch

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipe.to("cuda")

prompt = "Large language model writes python code, cold color palette, muted colors, detailed, 8k"
images2 = pipe(prompt=prompt, num_images_per_prompt=2).images
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images2[1]
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F46B024CAC0>

# %%
from diffusers import StableDiffusionXLPipeline
import torch

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipe.to("cuda")

prompt = "Large language model writes python code, cold color palette, muted colors, detailed, 8k"
images3 = pipe(prompt=prompt, num_images_per_prompt=2).images
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#images3[0]

# %%
#images3[1]

# %%
from diffusers import StableDiffusionXLPipeline
import torch

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipe.to("cuda")

prompt = "Large language model writes python code, cold color palette, muted colors, cyberpunk, detailed, 8k"
images4 = pipe(prompt=prompt, num_images_per_prompt=2, negative_prompt="snake, abstract").images
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#images4[0]

# %%
#images4[1]

# %%
from diffusers import StableDiffusionXLPipeline
import torch

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipe.to("cuda")

prompt = "Machine learning model writes python code, cold color palette, muted colors, cyberpunk, detailed, 8k"
images5 = pipe(prompt=prompt, num_images_per_prompt=2, negative_prompt="snake").images
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#images5[1]

# %%
import torch
from diffusers import StableDiffusionXLPipeline

device = "cuda"
model_id = "stabilityai/stable-diffusion-xl-base-1.0"
file = "seed_test_"

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", 
    torch_dtype=torch.float16, 
    variant="fp16", 
    use_safetensors=True
)
pipe.to("cuda")

num_images = 2
width = 512
height = 512

generator = torch.Generator("cuda").manual_seed(333)
prompt = "Large language model writes software code, detailed, 8k"
images7 = pipe(prompt=prompt, num_images_per_prompt=2, generator=generator).images
#images6 = pipe(prompt=prompt, num_images_per_prompt=2, negative_prompt="snake", generator=generator).images
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import torch
from diffusers import StableDiffusionXLPipeline

device = "cuda"
model_id = "stabilityai/stable-diffusion-xl-base-1.0"
file = "seed_test_"

pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", 
    torch_dtype=torch.float16, 
    variant="fp16", 
    use_safetensors=True
)
pipe.to("cuda")

num_images = 2
width = 512
height = 512

generator = torch.Generator("cuda").manual_seed(333)
prompt = "Large language model writes software code, face, detailed, 8k"
images8 = pipe(prompt=prompt, negative_prompt="human", num_images_per_prompt=2, generator=generator).images
#images6 = pipe(prompt=prompt, num_images_per_prompt=2, negative_prompt="snake", generator=generator).images
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#images8[0]

# %%
#images8[1]

# %%
import torch
from diffusers import StableDiffusionXLPipeline


for x in range(50):
    pipe = StableDiffusionXLPipeline.from_pretrained(
        "stabilityai/stable-diffusion-xl-base-1.0", 
        torch_dtype=torch.float16, 
        variant="fp16", 
        use_safetensors=True
    )
    pipe.to("cuda")
    
    seed = 1622 + x
    generator = torch.Generator("cuda").manual_seed(seed)
#    prompt = "Machine learning model generates software code"
    #222-372
#    prompt = "large language model writes software code, abstract"
    #422-472
#    prompt = "large language model generates software code, artificial, cyberpunk"
    #522-572
#    prompt = "large language model generates software code, artificial, cyberpunk, bright, silhouette"
    #622-672, 722-772
#    prompt = "large language model generates software code, artificial, cyberpunk, bright, silhouette, orchestrator, observer"
    #822-872
#    prompt = "large language model generates software code, artificial, cyberpunk, bright, silhouette, orchestrator, observer, computer"
    #922-972
#    prompt = "artifical intelligence generates software code, artificial, bright, silhouette, orchestrator, observer, computer"
    #1022-1072
#    prompt = "machine learning model generates software code, artificial, bright, silhouette, orchestrator, observer, computer, abstract"
    #1122-1172
#    prompt = "machine learning model generates software code, artificial, bright, silhouette, orchestrator, observer, computer"
    #1222-1272
#    prompt = "machine learning model generates software code, artificial, bright, silhouette, orchestrator, observer, computer, deus ex machine"
    #1322-1372
#    prompt = "machine learning model generates software code, artificial, cyberpunk, bright, silhouette, orchestrator, observer, computer, deus ex machine"
    #1422-1472
#    prompt = "machine learning model writes software code, artificial, cyberpunk, dystopian, silhouette, observer, deus ex machine"
    #1522-1572
#    prompt = "machine learning model writes software, cyberpunk, dystopian, silhouette, observer, deus ex machine, basement"
    #1622-1672
    prompt = "machine learning model writes programs, cyberpunk, dystopian, silhouette, observer, deus ex machine, basement, abstract"
    images_x = pipe(prompt=prompt, 
                    #negative_prompt="humanoid, android, person",
                    #722-752
                    #negative_prompt="corridor", 
                    #1022-1072+
                    negative_prompt="portrait", 
                    num_images_per_prompt=2,
                    guidance_scale=7.5,
                    generator=generator).images
    images_x[0].save(f"../data/llm_{seed}_1.jpg")
    images_x[1].save(f"../data/llm_{seed}_2.jpg")
